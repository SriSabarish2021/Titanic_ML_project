# %% [markdown]
# My First Project on the dataset of titanic

# %%
import pandas as pd 
import numpy as np
import matplotlib as mpt
import seaborn as sab

from sklearn.model_selection import train_test_split,StratifiedGroupKFold,GridSearchCV

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

from sklearn.pipeline import Pipeline,make_pipeline

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
data_gender=pd.read_csv("gender_submission.csv")
data_test=pd.read_csv("test.csv")
data_train=pd.concat([pd.read_csv("train.csv"),data_test])

# %%
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data_train=data_train.drop(columns="Name")

# %%
array=["male","female"]
chnage_sex=OrdinalEncoder(categories=[array])
data_train["Sex"]=chnage_sex.fit_transform(data_train[["Sex"]])

# %%
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1       0.0       3  0.0  22.0      1      0         A/5 21171
# 1            2       1.0       1  1.0  38.0      1      0          PC 17599
# 2            3       1.0       3  1.0  26.0      0      0  STON/O2. 3101282
# 3            4       1.0       1  1.0  35.0      1      0            113803
# 4            5       0.0       3  0.0  35.0      0      0            373450
# 5            6       0.0       3  0.0   NaN      0      0            330877
# 6            7       0.0       1  0.0  54.0      0      0             17463
# 7            8       0.0       3  0.0   2.0      3      1            349909
# 8            9       1.0       3  1.0  27.0      0      2            347742
# 9           10       1.0       2  1.0  14.0      1      0            237736
#
#       Fare Cabin Embarked
# 0   7.2500   NaN        S
# 1  71.2833   C85        C
# 2   7.9250   NaN        S
# ...

# %%
data=SimpleImputer(strategy="mean",add_indicator=True)
data_train["Age"]=data.fit_transform(data_train[["Age"]])

# %%
#survived_null=SimpleImputer(strategy="constant",fill_value=0.5)
#data_train["Survived"]=survived_null.fit_transform(data_train[["Survived"]])

# %%
data_train = data_train.dropna(subset=["Survived"])

# %%
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch  \
# 0            1       0.0       3  0.0  22.000000      1      0
# 1            2       1.0       1  1.0  38.000000      1      0
# 2            3       1.0       3  1.0  26.000000      0      0
# 3            4       1.0       1  1.0  35.000000      1      0
# 4            5       0.0       3  0.0  35.000000      0      0
# 5            6       0.0       3  0.0  29.881138      0      0
# 6            7       0.0       1  0.0  54.000000      0      0
# 7            8       0.0       3  0.0   2.000000      3      1
# 8            9       1.0       3  1.0  27.000000      0      2
# 9           10       1.0       2  1.0  14.000000      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# ...

# %%
data_train=data_train.drop(columns="Ticket")

# %%
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare Cabin  \
# 0            1       0.0       3  0.0  22.000000      1      0   7.2500   NaN
# 1            2       1.0       1  1.0  38.000000      1      0  71.2833   C85
# 2            3       1.0       3  1.0  26.000000      0      0   7.9250   NaN
# 3            4       1.0       1  1.0  35.000000      1      0  53.1000  C123
# 4            5       0.0       3  0.0  35.000000      0      0   8.0500   NaN
# 5            6       0.0       3  0.0  29.881138      0      0   8.4583   NaN
# 6            7       0.0       1  0.0  54.000000      0      0  51.8625   E46
# 7            8       0.0       3  0.0   2.000000      3      1  21.0750   NaN
# 8            9       1.0       3  1.0  27.000000      0      2  11.1333   NaN
# 9           10       1.0       2  1.0  14.000000      1      0  30.0708   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S
# 5        Q
# 6        S
# ...

# %%
data_train["Embarked"].isna().sum()
# Out:
# np.int64(2)

# %%
embark_nan=SimpleImputer(strategy="most_frequent")
data_train[["Embarked"]]=embark_nan.fit_transform(data_train[["Embarked"]])

# %%
data_train["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
array_embrk=["S","C","Q"]
embark_convert=OrdinalEncoder(categories=[array_embrk])
data_train["Embarked"]=embark_convert.fit_transform(data_train[["Embarked"]])

# %%
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare Cabin  \
# 0            1       0.0       3  0.0  22.000000      1      0   7.2500   NaN
# 1            2       1.0       1  1.0  38.000000      1      0  71.2833   C85
# 2            3       1.0       3  1.0  26.000000      0      0   7.9250   NaN
# 3            4       1.0       1  1.0  35.000000      1      0  53.1000  C123
# 4            5       0.0       3  0.0  35.000000      0      0   8.0500   NaN
# 5            6       0.0       3  0.0  29.881138      0      0   8.4583   NaN
# 6            7       0.0       1  0.0  54.000000      0      0  51.8625   E46
# 7            8       0.0       3  0.0   2.000000      3      1  21.0750   NaN
# 8            9       1.0       3  1.0  27.000000      0      2  11.1333   NaN
# 9           10       1.0       2  1.0  14.000000      1      0  30.0708   NaN
#
#    Embarked
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0
# 5       2.0
# 6       0.0
# ...

# %%
data_train=data_train.drop(columns="Cabin")

# %%
data_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  Sex        Age  SibSp  Parch     Fare  \
# 0            1       0.0       3  0.0  22.000000      1      0   7.2500
# 1            2       1.0       1  1.0  38.000000      1      0  71.2833
# 2            3       1.0       3  1.0  26.000000      0      0   7.9250
# 3            4       1.0       1  1.0  35.000000      1      0  53.1000
# 4            5       0.0       3  0.0  35.000000      0      0   8.0500
# 5            6       0.0       3  0.0  29.881138      0      0   8.4583
# 6            7       0.0       1  0.0  54.000000      0      0  51.8625
# 7            8       0.0       3  0.0   2.000000      3      1  21.0750
# 8            9       1.0       3  1.0  27.000000      0      2  11.1333
# 9           10       1.0       2  1.0  14.000000      1      0  30.0708
#
#    Embarked
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0
# 5       2.0
# 6       0.0
# 7       0.0
# 8       0.0
# 9       1.0

# %%
data_y=data_train.pop(item="Survived")
#X_test,X_train,y_test,y_train=train_test_split(data_x,data_y,test_size=0.3,random_state=40)

# %%
data_y
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, Length: 891, dtype: float64

# %%
data_x=data_train
data_x.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
fare_null=SimpleImputer(strategy="mean")
data_x[["Fare"]]=fare_null.fit_transform(data_x[["Fare"]])

# %%
data_y.isna().sum()
# Out:
# np.int64(0)

# %%
data_y
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 886    0.0
# 887    1.0
# 888    0.0
# 889    1.0
# 890    0.0
# Name: Survived, Length: 891, dtype: float64

# %%
data_x=data_x.drop(columns="PassengerId")

# %%
data_x
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3  0.0  22.000000      1      0   7.2500       0.0
# 1         1  1.0  38.000000      1      0  71.2833       1.0
# 2         3  1.0  26.000000      0      0   7.9250       0.0
# 3         1  1.0  35.000000      1      0  53.1000       0.0
# 4         3  0.0  35.000000      0      0   8.0500       0.0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2  0.0  27.000000      0      0  13.0000       0.0
# 887       1  1.0  19.000000      0      0  30.0000       0.0
# 888       3  1.0  29.881138      1      2  23.4500       0.0
# 889       1  0.0  26.000000      0      0  30.0000       1.0
# 890       3  0.0  32.000000      0      0   7.7500       2.0
#
# [891 rows x 7 columns]

# %%
X_test,X_train,y_test,y_train=train_test_split(data_x,data_y,test_size=0.3,random_state=40)

# %%
X_test.shape
# Out:
# (623, 7)

# %%
y_test.shape
# Out:
# (623,)

# %%
y_train.shape
# Out:
# (268,)

# %%
X_train.shape
# Out:
# (268, 7)

# %% [markdown]
# Lest apply the ML  model that i have learned

# %%
X_train.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# KN Neighbour ALGO

# %%
Kn_model=KNeighborsClassifier(n_neighbors=8)
kn_fit=Kn_model.fit(X_train,y_train)

# %%
y_pred=kn_fit.predict(X_test)

# %%
kn_fit.score(X_test,y_test)
# Out:
# 0.7078651685393258

# %%
#kn model analysis
confusion_matrix=confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[259], line 2
#       1 #kn model analysis
# ----> 2 confusion_matrix=confusion_matrix(y_test,y_pred)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
classification_report=classification_report(y_test,y_pred)
classification_report
# Out:
# '              precision    recall  f1-score   support\n\n         0.0       0.73      0.86      0.79       393\n         1.0       0.65      0.44      0.53       230\n\n    accuracy                           0.71       623\n   macro avg       0.69      0.65      0.66       623\nweighted avg       0.70      0.71      0.69       623\n'

# %% [markdown]
# Desision Tree ALGO

# %%
decision_tree=DecisionTreeClassifier(criterion='entropy',min_samples_split=20,max_depth=30,ccp_alpha=0.04)

# %%
decision_model=decision_tree.fit(X_train,y_train)

# %%
decision_model_score=decision_model.score(X_test,y_test)

# %%
decision_model_score
# Out:
# 0.78330658105939

# %%
decision_model_predict=decision_model.predict(X_test)

# %% [markdown]
# Random Forest ALGO

# %%
random_forest=RandomForestClassifier()

# %%
random_forest_model=random_forest.fit(X_train,y_train)

# %%
random_forest_score=random_forest_model.score(X_test,y_test)
random_forest_score
# Out:
# 0.7752808988764045

# %%
param=[{#"criterion":["entropy","gini","log_loss"],
        #"max_depth":[10,30,20],
        "min_samples_split":[10,8,12],
        "ccp_alpha":[0.04,0.05,0.06],
        "n_estimators":[500,1000,1500]}]

# %%
from sklearn.model_selection import GridSearchCV

# %%
rand_multi=GridSearchCV(random_forest,param,cv=2,n_jobs=-1,scoring="accuracy")

# %%
rand_multi_model=rand_multi.fit(X_train,y_train)

# %%
rand_multi_model_score=rand_multi_model.score(X_test,y_test)

# %%
rand_multi_model_score
# Out:
# 0.8138041733547352

# %%
rand_multi.best_estimator_
# Out:
# RandomForestClassifier(ccp_alpha=0.04, criterion='entropy', max_depth=60,
#                        min_samples_split=10, n_estimators=500)

# %% [markdown]
# Naive Bayes ALGO

# %%
Nb_algo=GaussianNB(var_smoothing=0.15)

# %%
Nb_algo_model=Nb_algo.fit(X_train,y_train)

# %%
Nb_algo_model.score(X_test,y_test)
# Out:
# 0.6709470304975923

# %% [markdown]
# SUPPORT VECTOR MACHINE ALGO

# %%
param_for_SVM=[{
    "kernel":["poly","linear"],
    "C":[0.1,0.2],
    "gamma":[1,2]
}]

# %%
#SVM_algo=SVC()

#SVM_grid_search=GridSearchCV(SVM_algo,param_for_SVM,scoring="accuracy",n_jobs=-1)

SVM_algo=SVC(kernel='linear',C=0.1,gamma=1)

# %%
#svm_model_eval=SVM_grid_search.fit(X_train,y_train)

svm_model_eval=SVM_algo.fit(X_train,y_train)

# %%
svm_model_eval.score(X_test,y_test)
# Out:
# 0.7865168539325843
